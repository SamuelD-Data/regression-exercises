# %% [markdown]
# ### Write a function named plot_variable_pairs that accepts a dataframe as input and plots all of the pairwise relationships along with the regression line for each pair.

# %%
# imports
from wrangle import wrangle_telco
from explore import plot_variable_pairs
from explore import months_to_years
from explore import plot_categorical_and_continuous

import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# acquiring data using function from previous exercise
df = wrangle_telco()
df.head()
# Out:
#   customer_id  monthly_charges  tenure  total_charges
# 0  0013-SMEOE           109.70      71        7904.25
# 1  0014-BMAQU            84.65      63        5377.80
# 2  0016-QLJIS            90.45      65        5957.90
# 3  0017-DINOC            45.20      54        2460.55
# 4  0017-IUDMW           116.80      72        8456.75

# %%
# plot_variable_pairs function

# def plot_variable_pairs(df):
 #   return sns.pairplot(df, kind = 'reg')

# %%
# plotting variable pairs via function from external file
plot_variable_pairs(df)

# %% [markdown]
# ### Write a function named months_to_years that accepts your telco churn dataframe and returns a dataframe with a new feature tenure_years, in complete years as a customer.

# %%
# months_to_years function

# def months_to_years(df):
    # df['tenure_years'] = round(df['tenure'] / 12)
    # return df

# %%
# using function from external file to add tenure_years column (rounded)
mty_df = months_to_years(df)

mty_df.head()
# Out:
#   customer_id  monthly_charges  tenure  total_charges  tenure_years
# 0  0013-SMEOE           109.70      71        7904.25           6.0
# 1  0014-BMAQU            84.65      63        5377.80           5.0
# 2  0016-QLJIS            90.45      65        5957.90           5.0
# 3  0017-DINOC            45.20      54        2460.55           4.0
# 4  0017-IUDMW           116.80      72        8456.75           6.0

# %% [markdown]
# ### Write a function named plot_categorical_and_continuous_vars that accepts your dataframe and the name of the columns that hold the continuous and categorical features and outputs 3 different plots for visualizing a categorical variable and a continuous variable.

# %%
# plot_categorical_data function

# def plot_categorical_and_continuous(df, cat, con):
    # plt.rc('figure', figsize = (19,10))
    # plt.subplot(221)
    # swarmplot = sns.swarmplot(data = df, x = cat, y = con)
    # plt.subplot(222)
    # violin = sns.violinplot(data = df, x = cat, y = con)
    # plt.subplot(223)
    # violin = sns.boxplot(data = df, x = cat, y = con)

# %%
# adding categorical column, state, to df
# column holds the state a customer is from (randomly chosen from tx and ny)
np.random.seed(13)
df['state'] = np.random.choice(['TX', 'NY'], df.shape[0])
df.head()
# Out:
#   customer_id  monthly_charges  tenure  total_charges  tenure_years state
# 0  0013-SMEOE           109.70      71        7904.25           6.0    TX
# 1  0014-BMAQU            84.65      63        5377.80           5.0    TX
# 2  0016-QLJIS            90.45      65        5957.90           5.0    TX
# 3  0017-DINOC            45.20      54        2460.55           4.0    TX
# 4  0017-IUDMW           116.80      72        8456.75           6.0    TX

# %%
# using function from external file to create swarm, violin, and box plot
plot_categorical_and_continuous(df, 'state', 'monthly_charges')

# %% [markdown]
# ### Save the functions you have written to create visualizations in a file named explore.py. Rewrite your notebook code so that you are using the functions imported from this file.

# %%
# 1) Functions added to external explore.py file
# 2) Code above now calls functions from external file to perform visualizations as well as add tenure years column
# 3) Previous work was commented out to maintain record of work

# %% [markdown]
# ### Explore your dataset with any other visualizations you think will be helpful.

# %%
# if the state values were not randomly assigned and were instead, real data
# we could use this barplot to observe yearly tenures with respect to state
# ie. are customers from one state staying with us longer?
sns.barplot(data = df, y='tenure_years', x='state')

# %%
# using heatmap to see which variables have strong correlations with each other
# this is one way of identifying relationships and leads to hypothesis formation
sns.heatmap(df.corr(), cmap = 'Reds', annot = True)

# %% [markdown]
# ### In a seperate notebook, use the functions you have developed in this exercise with the mall customers dataset.

# %%
# acquiring mall data from csv
mall = pd.read_csv('mall_customers_df.csv')

# dropping extra column that was added while acquiring
mall = mall.drop(columns = 'Unnamed: 0')

# previewing data
mall.head()
# Out:
#    customer_id  gender  age  annual_income  spending_score
# 0            1    Male   19             15              39
# 1            2    Male   21             15              81
# 2            3  Female   20             16               6
# 3            4  Female   23             16              77
# 4            5  Female   31             17              40

# %%
# using external function to plot each combination of variables
plot_variable_pairs(mall)

# %%
# using external function to create swarm, violin, and box plot of gender and annual income data from mall dataset 
plot_categorical_and_continuous(mall, 'gender', 'annual_income')
